# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso

# 1. Define input array X with angles from 60 deg to 300 deg converted in radians.
X = np.arange(60, 300, 1)
X = np.radians(X)

# 2. Compute Y as Y=Sin(X)+K
# where K is a random number generated from normal distribution with zero mean and 0.15 std dev.
K = np.random.normal(0, 0.15, X.shape)
Y = np.sin(X) + K

# 3. Create Linear Regression model, and different Non-Linear Regression models of 3,6,9,12 and 15th degree polynomial 
# on data created in step-1 and step-2. (You may optimize the model for max. of 100 iterations using Gradient Descent)
# 4. Plot the created models for the power of 1, 3,6,9,12 and 15, and print the SSE, Coefficients for the plotted models.
degree = [1, 3, 6, 9, 12, 15]
for i in degree:
    poly = PolynomialFeatures(degree=i)
    X_poly = poly.fit_transform(X.reshape(-1, 1))
    regressor = LinearRegression()
    regressor.fit(X_poly, Y)
    y_pred = regressor.predict(X_poly)
    print("SSE for polynomial of degree", i,
          "is", mean_squared_error(Y, y_pred))
    print("Coefficients for polynomial of degree", i, "are", regressor.coef_)
    plt.scatter(X, Y, color='blue')
    plt.plot(X, y_pred, color='red')
    plt.title("Polynomial of degree " + str(i))
    plt.show()

# 5. Add the L1 and L2 regularization to the nonlinear regression model with 15th degree polynomial created in Step 3. 
# (Optimize for Max. of 100 Iterations and lambda values [1e-10,1e-8,1e-4,1e-2,1,10,20])
# 6. Plot the Lasso (L1) and Ridge (L2) regression models for lambda values [1e-10,1e-8,1e-4,1e-2,1,10,20], 
# and print the SSE, Coefficients for the plotted models.
poly = PolynomialFeatures(degree=15)
X_poly = poly.fit_transform(X.reshape(-1, 1))
lambda_values = [1e-10, 1e-8, 1e-4, 1e-2, 1, 10, 20]
for i in lambda_values:
    lasso_regressor = Lasso(alpha=i, max_iter=100)
    lasso_regressor.fit(X_poly, Y)
    y_pred = lasso_regressor.predict(X_poly)
    print("SSE for Lasso regression with lambda", i, "is",
          mean_squared_error(Y, y_pred))
    print("Coefficients for Lasso regression with lambda", i, "are", lasso_regressor.coef_)
    plt.scatter(X, Y, color='blue')
    plt.plot(X, y_pred, color='red')
    plt.title("Lasso regression with lambda " + str(i))
    plt.show()

for i in lambda_values:
    ridge_regressor = Ridge(alpha=i, max_iter=100)
    ridge_regressor.fit(X_poly, Y)
    y_pred = ridge_regressor.predict(X_poly)
    print("SSE for Ridge regression with lambda", i, "is",
          mean_squared_error(Y, y_pred))
    print("Coefficients for Ridge regression with lambda", i, "are", ridge_regressor.coef_)
    plt.scatter(X, Y, color='blue')
    plt.plot(X, y_pred, color='red')
    plt.title("Ridge regression with lambda " + str(i))
    plt.show()
# Out:
# SSE for polynomial of degree 1 is 0.05100692404554323
# Coefficients for polynomial of degree 1 are [ 0.         -0.62106356]
# SSE for polynomial of degree 3 is 0.022768184033437427
# Coefficients for polynomial of degree 3 are [ 0.          2.63788426 -1.13945602  0.12097947]
# SSE for polynomial of degree 6 is 0.02220179060502776
# Coefficients for polynomial of degree 6 are [ 0.          1.81457543 -1.48044007  0.8310414  -0.31875846  0.05868883
#  -0.00390868]
# SSE for polynomial of degree 9 is 0.021973034471078724
# Coefficients for polynomial of degree 9 are [ 0.00000000e+00  1.95125231e+02 -2.91599435e+02  2.43748379e+02
#  -1.25702641e+02  4.15529470e+01 -8.83436000e+00  1.16859768e+00
#  -8.74938455e-02  2.83042223e-03]
# SSE for polynomial of degree 12 is 0.021328506786630858
# Coefficients for polynomial of degree 12 are [ 0.00000000e+00  2.56484428e+02  4.38224902e+02 -1.88173570e+03
#   2.72417082e+03 -2.26548362e+03  1.22326664e+03 -4.48724144e+02
#   1.13122485e+02 -1.93312765e+01  2.14158287e+00 -1.38839533e-01
#   3.99970018e-03]
# SSE for polynomial of degree 15 is 0.021271560654132896
# Coefficients for polynomial of degree 15 are [ 0.00000000e+00  9.93632164e+01  2.85963809e+01 -1.11620873e+02
#  -3.75786625e+01  1.33422470e+02  3.43420805e+00 -1.57645443e+02
#   1.64608900e+02 -9.04335440e+01  3.14974234e+01 -7.32208896e+00
#   1.13854458e+00 -1.14103442e-01  6.67898559e-03 -1.73755875e-04]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.484e+00, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 1e-10 is 0.02903369397896928
# Coefficients for Lasso regression with lambda 1e-10 are [ 0.00000000e+00 -4.53840013e-02 -9.95522536e-02 -7.82113177e-03
#  -2.62562138e-04  6.69368164e-05  2.12884604e-05  4.24789066e-06
#   7.13097403e-07  1.07293747e-07  1.45514666e-08  1.70355854e-09
#   1.42415520e-10 -2.81000507e-12 -5.34462898e-12 -1.77782800e-12]
# SSE for Lasso regression with lambda 1e-08 is 0.02903369127639162
# Coefficients for Lasso regression with lambda 1e-08 are [ 0.00000000e+00 -4.53837284e-02 -9.95523171e-02 -7.82113088e-03
#  -2.62561808e-04  6.69368596e-05  2.12884657e-05  4.24789117e-06
#   7.13097440e-07  1.07293748e-07  1.45514659e-08  1.70355832e-09
#   1.42415468e-10 -2.81001601e-12 -5.34463112e-12 -1.77782841e-12]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.484e+00, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 0.0001 is 0.029006439754588734
# Coefficients for Lasso regression with lambda 0.0001 are [ 0.00000000e+00 -4.26272955e-02 -1.00193321e-01 -7.81220446e-03
#  -2.59234154e-04  6.73729555e-05  2.13419588e-05  4.25297605e-06
#   7.13475557e-07  1.07296883e-07  1.45441015e-08  1.70126000e-09
#   1.41882443e-10 -2.92051769e-12 -5.36627429e-12 -1.78193013e-12]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.484e+00, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.726e+00, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 0.01 is 0.028645015147500483
# Coefficients for Lasso regression with lambda 0.01 are [ 0.00000000e+00  0.00000000e+00 -1.11860843e-01 -8.27133216e-03
#  -1.03502300e-04  8.97698992e-05  2.41672746e-05  4.47634014e-06
#   7.21566633e-07  1.05041290e-07  1.37072524e-08  1.50108704e-09
#   1.00291071e-10 -1.10015722e-11 -6.87842163e-12 -2.05843231e-12]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.487e+00, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 1 is 0.029793407640315867
# Coefficients for Lasso regression with lambda 1 are [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -1.43987780e-02
#  -5.93466047e-03  1.83961364e-05  9.99300699e-05  1.24838275e-05
#   1.60348929e-06  1.96212787e-07  2.12387390e-08  1.64799365e-09
#  -4.09279786e-11 -5.99959072e-11 -1.90520313e-11 -4.73256278e-12]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.186e+01, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 10 is 0.055597137494799644
# Coefficients for Lasso regression with lambda 10 are [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -2.13361344e-03 -0.00000000e+00  2.44323668e-05
#   3.76548358e-06  4.65416406e-07  5.52626788e-08  5.76064274e-09
#   4.03527048e-10 -2.44524186e-11 -1.94232738e-11 -5.84085345e-12]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.584e+01, tolerance: 1.476e-02
#   model = cd_fast.enet_coordinate_descent(
# SSE for Lasso regression with lambda 20 is 0.061835355061906
# Coefficients for Lasso regression with lambda 20 are [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -1.64016897e-03 -9.47666500e-05  1.40853469e-05
#   4.59161122e-06  5.57047078e-07  6.68509995e-08  7.24884894e-09
#   5.85701865e-10 -4.66479457e-12 -1.78761682e-11 -5.87835492e-12]
# SSE for Ridge regression with lambda 1e-10 is 0.02127144040616565
# Coefficients for Ridge regression with lambda 1e-10 are [ 0.00000000e+00  1.45057293e+01  2.08338220e+02 -3.11929167e+02
#   6.64211655e+01  1.55653960e+02 -7.80995317e+01 -8.79106910e+01
#   1.28582304e+02 -7.76422018e+01  2.82584122e+01 -6.73511689e+00
#   1.06394729e+00 -1.07777784e-01  6.35723443e-03 -1.66326424e-04]
# SSE for Ridge regression with lambda 1e-08 is 0.021271748983665996
# Coefficients for Ridge regression with lambda 1e-08 are [ 0.00000000e+00  1.35041653e+02 -8.86302699e+00 -1.17117465e+02
#   3.27097683e-01  1.18384422e+02 -2.40629464e+01 -1.15526790e+02
#   1.35094819e+02 -7.74388630e+01  2.76066996e+01 -6.51350567e+00
#   1.02322231e+00 -1.03306272e-01  6.08028051e-03 -1.58838390e-04]
# SSE for Ridge regression with lambda 0.0001 is 0.02170507910314016
# Coefficients for Ridge regression with lambda 0.0001 are [ 0.00000000e+00  5.52971413e+00  1.40335400e+00 -3.08528968e+00
#  -2.20380954e+00  1.79695861e+00  2.11794084e+00 -1.58416339e+00
#  -1.18256734e+00  1.94800475e+00 -1.12907574e+00  3.71912300e-01
#  -7.59214054e-02  9.54932036e-03 -6.80797463e-04  2.11098847e-05]
# SSE for Ridge regression with lambda 0.01 is 0.021792853576844837
# Coefficients for Ridge regression with lambda 0.01 are [ 0.00000000e+00  1.22316200e-01  7.77324752e-02  8.11638803e-03
#   1.23941874e-02  5.37153374e-02  4.27548351e-03 -1.11293576e-01
#  -2.50671309e-02  1.74420048e-01 -1.50311330e-01  6.44214676e-02
#  -1.60455030e-02  2.36397854e-03 -1.91785978e-04  6.62213003e-06]
# SSE for Ridge regression with lambda 1 is 0.021802232297683292
# Coefficients for Ridge regression with lambda 1 are [ 0.00000000e+00  1.70235537e-02  3.85093648e-02  5.99174750e-02
#   6.69054608e-02  3.68565572e-02 -3.89972964e-02 -9.66093068e-02
#  -1.93905385e-02  1.81142686e-01 -1.62370548e-01  7.09542150e-02
#  -1.78739870e-02  2.65223404e-03 -2.16186192e-04  7.48847683e-06]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.75071e-23): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.5233e-22): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# SSE for Ridge regression with lambda 10 is 0.02199797969011699
# Coefficients for Ridge regression with lambda 10 are [ 0.00000000e+00  5.37721587e-03  9.53707311e-03  1.04273734e-02
#   6.24372261e-03 -2.30135429e-03 -9.41478533e-03 -6.07053435e-03
#   7.17163145e-03  8.12393725e-03 -1.34773216e-02  7.73505351e-03
#  -2.34650324e-03  4.01556571e-04 -3.67205200e-05  1.39915088e-06]
# C:\Users\Rahul Varma\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=3.19089e-22): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# SSE for Ridge regression with lambda 20 is 0.022036963045300874
# Coefficients for Ridge regression with lambda 20 are [ 0.00000000e+00  2.47770004e-03  4.23474976e-03  4.34691826e-03
#   2.17643029e-03 -1.56302254e-03 -3.94570705e-03 -1.51656249e-03
#   3.63129271e-03  1.73382197e-03 -5.37453601e-03  3.71825821e-03
#  -1.26261421e-03  2.33583154e-04 -2.26173744e-05  9.00189647e-07]
