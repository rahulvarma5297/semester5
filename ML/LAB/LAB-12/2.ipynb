# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()

# %%
import matplotlib.pyplot as plt
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential()

model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
history = model.fit(X_train,y_train,epochs=20,validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 [==============================] - 13s 7ms/step - loss: 0.2814 - accuracy: 0.9180 - val_loss: 0.1501 - val_accuracy: 0.9542
# Epoch 2/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.1195 - accuracy: 0.9639 - val_loss: 0.1236 - val_accuracy: 0.9629
# Epoch 3/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0848 - accuracy: 0.9745 - val_loss: 0.0993 - val_accuracy: 0.9700
# Epoch 4/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0641 - accuracy: 0.9804 - val_loss: 0.1017 - val_accuracy: 0.9697
# Epoch 5/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0504 - accuracy: 0.9843 - val_loss: 0.0934 - val_accuracy: 0.9727
# Epoch 6/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0398 - accuracy: 0.9877 - val_loss: 0.1024 - val_accuracy: 0.9718
# Epoch 7/25
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0328 - accuracy: 0.9895 - val_loss: 0.1012 - val_accuracy: 0.9724
# Epoch 8/25
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.1188 - val_accuracy: 0.9694
# Epoch 9/25
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.1101 - val_accuracy: 0.9754
# Epoch 10/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.1177 - val_accuracy: 0.9725
# Epoch 11/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.1249 - val_accuracy: 0.9718
# Epoch 12/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.1460 - val_accuracy: 0.9707
# Epoch 13/25
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.1502 - val_accuracy: 0.9705
# Epoch 14/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.1389 - val_accuracy: 0.9728
# Epoch 15/25
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.1302 - val_accuracy: 0.9763
# Epoch 16/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1445 - val_accuracy: 0.9727
# Epoch 17/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.1608 - val_accuracy: 0.9718
# Epoch 18/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.1383 - val_accuracy: 0.9757
# Epoch 19/25
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.1744 - val_accuracy: 0.9722
# Epoch 20/25
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.1571 - val_accuracy: 0.9723
# Epoch 21/25
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.1804 - val_accuracy: 0.9719
# Epoch 22/25
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.1799 - val_accuracy: 0.9730
# Epoch 23/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.1676 - val_accuracy: 0.9751
# Epoch 24/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.1820 - val_accuracy: 0.9739
# Epoch 25/25
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.2073 - val_accuracy: 0.9708

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.argmax(axis=1)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9725

# %%
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])

# %%
plt.plot(history.history['val_accuracy'])
